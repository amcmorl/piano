# %%
import piano_control as pc

# %%
entries = pc.read_file('../Block-1_NEW.txt')

# %%
last_entry = entries[-1][0]

# %%
entries
# Out:
# [[0, 0, 3000],
#  [1, 1, 200],
#  [1, 0, 500],
#  [1, 12, 500],
#  [1, 0, 1500],
#  [1, 8, 100],
#  [1, 0, 2000],
#  [2, 1, 200],
#  [2, 0, 500],
#  [2, 8, 500],
#  [2, 0, 1500],
#  [2, 8, 100],
#  [2, 0, 2000],
#  [3, 1, 200],
#  [3, 0, 500],
#  [3, 12, 500],
#  [3, 0, 1500],
#  [3, 4, 100],
#  [3, 0, 2000],
#  [4, 1, 200],
#  [4, 0, 500],
#  [4, 8, 500],
#  [4, 0, 1500],
#  [4, 8, 100],
#  [4, 0, 2000],
#  [5, 1, 200],
#  [5, 0, 500],
#  [5, 12, 500],
#  [5, 0, 1500],
#  [5, 8, 100],
#  [5, 0, 2000],
#  [6, 1, 200],
#  [6, 0, 500],
#  [6, 4, 500],
#  [6, 0, 1500],
#  [6, 0, 100],
#  [6, 0, 2000],
#  [7, 1, 200],
#  [7, 0, 500],
#  [7, 4, 500],
#  [7, 0, 1500],
#  [7, 4, 100],
#  [7, 0, 2000],
#  [8, 1, 200],
#  [8, 0, 500],
#  [8, 12, 500],
#  [8, 0, 1500],
#  [8, 8, 100],
#  [8, 0, 2000],
#  [9, 1, 200],
#  [9, 0, 500],
#  [9, 4, 500],
#  [9, 0, 1500],
#  [9, 4, 100],
#  [9, 0, 2000],
#  [10, 1, 200],
#  [10, 0, 500],
#  [10, 8, 500],
#  [10, 0, 1500],
#  [10, 8, 100],
# ...

# %%
mylist = [0,1,2,5,3,8]

# %%
mylist[-1]
# Out:
# 8

# %%
(1 << 5)
# Out:
# 32

# %%
0b11011000000 >> 8
# Out:
# 6

# %%
(1 << 0)
# Out:
# 1

# %%
(1 << 10)
# Out:
# 1024

# %%
0B01000000000
# Out:
# 512

# %%
0b00000000 << 8
# Out:
# 32768

# %%
0b01000000 << 8
# Out:
# 16384

# %%
2**15
# Out:
# 32768
